# %%
import pandas as pd

data = pd.read_csv("salaries_by_college_major.csv")
# Out:
# Unable to start Kernel 'Python 3.11.5' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import pandas as pd

data = pd.read_csv("C:/Users/Front Desk/Documents/Niyi/100DaysOfPythonCoding/#Day71/salaries_by_college_major.csv")

# %%
data.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 3      HASS
# 4  Business

# %%
data.tail()
# Out:
#       Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 46             Psychology                 35900.0                   60400.0
# 47               Religion                 34100.0                   52000.0
# 48              Sociology                 36500.0                   58200.0
# 49                Spanish                 34000.0                   53100.0
# 50  Source: PayScale Inc.                     NaN                       NaN
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS
# 50                                NaN                                NaN   NaN

# %%
data.isna()
# Out:
#     Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0                 False                   False                     False
# 1                 False                   False                     False
# 2                 False                   False                     False
# 3                 False                   False                     False
# 4                 False                   False                     False
# 5                 False                   False                     False
# 6                 False                   False                     False
# 7                 False                   False                     False
# 8                 False                   False                     False
# 9                 False                   False                     False
# 10                False                   False                     False
# 11                False                   False                     False
# ...

# %%
data.dropna()
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                 46000.0
# 1                  Aerospace Engineering                 57700.0
# 2                            Agriculture                 42600.0
# 3                           Anthropology                 36800.0
# 4                           Architecture                 41600.0
# 5                            Art History                 35800.0
# 6                                Biology                 38800.0
# 7                    Business Management                 43000.0
# 8                   Chemical Engineering                 63200.0
# 9                              Chemistry                 42600.0
# 10                     Civil Engineering                 53900.0
# 11                        Communications                 38100.0
# 12                  Computer Engineering                 61400.0
# ...

# %%
clean_data = data.dropna()

# %%
clean_data.tail()
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 45   Political Science                 40800.0                   78200.0
# 46          Psychology                 35900.0                   60400.0
# 47            Religion                 34100.0                   52000.0
# 48           Sociology                 36500.0                   58200.0
# 49             Spanish                 34000.0                   53100.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 45                            41200.0                           168000.0  HASS
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS

# %%
data.tail()
# Out:
#       Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 46             Psychology                 35900.0                   60400.0
# 47               Religion                 34100.0                   52000.0
# 48              Sociology                 36500.0                   58200.0
# 49                Spanish                 34000.0                   53100.0
# 50  Source: PayScale Inc.                     NaN                       NaN
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS
# 50                                NaN                                NaN   NaN

# %%
clean_data.shape
# Out:
# (50, 6)

# %%
clean_data.column
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-bf72cdd2c332> in ?()
# ----> 1 clean_data.column
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'column'

# %%
clean_data.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
clean_data["Mid-Career 90th Percentile Salary"]
# Out:
# 0     152000.0
# 1     161000.0
# 2     150000.0
# 3     138000.0
# 4     136000.0
# 5     125000.0
# 6     135000.0
# 7     147000.0
# 8     194000.0
# 9     148000.0
# 10    148000.0
# 11    143000.0
# 12    162000.0
# 13    154000.0
# 14    171000.0
# 15    107000.0
# 16    153000.0
# 17    210000.0
# 18    102000.0
# 19    168000.0
# 20    133000.0
# 21    136000.0
# 22    195000.0
# 23    111000.0
# 24    132000.0
# 25    156000.0
# 26    112000.0
# 27    101000.0
# 28    149000.0
# 29    124000.0
# 30    173000.0
# 31    129000.0
# 32    107000.0
# 33    157000.0
# 34    145000.0
# 35    146000.0
# 36    175000.0
# 37    183000.0
# 38    163000.0
# 39    134000.0
# 40     98300.0
# 41     99200.0
# 42    168000.0
# 43    124000.0
# 44    178000.0
# 45    168000.0
# 46    127000.0
# 47     96400.0
# 48    118000.0
# 49     96400.0
# Name: Mid-Career 90th Percentile Salary, dtype: float64

# %%
clean_data["Mid-Career 90th Percentile Salary"].max()
# Out:
# 210000.0

# %%
clean_data["Mid-Career 90th Percentile Salary"].idxmax()
# Out:
# 17

# %%
clean_data["Undergraduate Major"][17]
# Out:
# 'Economics'

# %%
clean_data['Mid-Career 90th Percentile Salary'] - clean_data['Mid-Career 10th Percentile Salary']
# Out:
# 0     109800.0
# 1      96700.0
# 2     113700.0
# 3     104200.0
# 4      85400.0
# 5      96200.0
# 6      98100.0
# 7     108200.0
# 8     122100.0
# 9     102700.0
# 10     84600.0
# 11    105500.0
# 12     95900.0
# 13     98000.0
# 14    114700.0
# 15     74800.0
# 16    116300.0
# 17    159400.0
# 18     72700.0
# 19     98700.0
# 20     99600.0
# 21    102100.0
# 22    147800.0
# 23     70000.0
# 24     92000.0
# 25    111000.0
# 26     76000.0
# 27     66400.0
# 28    112000.0
# 29     88500.0
# 30    115900.0
# 31     84500.0
# 32     71300.0
# 33    118800.0
# 34    106600.0
# 35    100700.0
# 36    132900.0
# 37    137800.0
# 38     99300.0
# 39    107300.0
# 40     50700.0
# 41     65300.0
# 42    132500.0
# 43     57600.0
# 44    122000.0
# 45    126800.0
# 46     95400.0
# 47     66700.0
# 48     87300.0
# 49     65400.0
# dtype: float64

# %%
clean_data['Mid-Career 90th Percentile Salary'].subtract(clean_data['Mid-Career 10th Percentile Salary'])
# Out:
# 0     109800.0
# 1      96700.0
# 2     113700.0
# 3     104200.0
# 4      85400.0
# 5      96200.0
# 6      98100.0
# 7     108200.0
# 8     122100.0
# 9     102700.0
# 10     84600.0
# 11    105500.0
# 12     95900.0
# 13     98000.0
# 14    114700.0
# 15     74800.0
# 16    116300.0
# 17    159400.0
# 18     72700.0
# 19     98700.0
# 20     99600.0
# 21    102100.0
# 22    147800.0
# 23     70000.0
# 24     92000.0
# 25    111000.0
# 26     76000.0
# 27     66400.0
# 28    112000.0
# 29     88500.0
# 30    115900.0
# 31     84500.0
# 32     71300.0
# 33    118800.0
# 34    106600.0
# 35    100700.0
# 36    132900.0
# 37    137800.0
# 38     99300.0
# 39    107300.0
# 40     50700.0
# 41     65300.0
# 42    132500.0
# 43     57600.0
# 44    122000.0
# 45    126800.0
# 46     95400.0
# 47     66700.0
# 48     87300.0
# 49     65400.0
# dtype: float64

# %%
spread_col = clean_data['Mid-Career 90th Percentile Salary'].subtract(clean_data['Mid-Career 10th Percentile Salary'])
clean_data.insert(1, 'Spread', spread_col)
clean_data.head()
# Out:
#      Undergraduate Major    Spread  Starting Median Salary  \
# 0             Accounting  109800.0                 46000.0
# 1  Aerospace Engineering   96700.0                 57700.0
# 2            Agriculture  113700.0                 42600.0
# 3           Anthropology  104200.0                 36800.0
# 4           Architecture   85400.0                 41600.0
#
#    Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 0                   77100.0                            42200.0
# 1                  101000.0                            64300.0
# 2                   71900.0                            36300.0
# 3                   61500.0                            33800.0
# 4                   76800.0                            50600.0
#
#    Mid-Career 90th Percentile Salary     Group
# 0                           152000.0  Business
# 1                           161000.0      STEM
# 2                           150000.0  Business
# ...

# %%
low_risk = clean_data.sort_values('Spread')
low_risk[['Undergraduate Major', 'Spread']].head()
# Out:
#            Undergraduate Major   Spread
# 40                     Nursing  50700.0
# 43         Physician Assistant  57600.0
# 41                   Nutrition  65300.0
# 49                     Spanish  65400.0
# 27  Health Care Administration  66400.0

# %%
low_risk = clean_data.sort_values('Spread')
low_risk.head()
# Out:
#            Undergraduate Major   Spread  Starting Median Salary  \
# 40                     Nursing  50700.0                 54200.0
# 43         Physician Assistant  57600.0                 74300.0
# 41                   Nutrition  65300.0                 39900.0
# 49                     Spanish  65400.0                 34000.0
# 27  Health Care Administration  66400.0                 38800.0
#
#     Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 40                   67000.0                            47600.0
# 43                   91700.0                            66400.0
# 41                   55300.0                            33900.0
# 49                   53100.0                            31000.0
# 27                   60600.0                            34600.0
#
#     Mid-Career 90th Percentile Salary     Group
# 40                            98300.0  Business
# 43                           124000.0      STEM
# ...

# %%
low_risk = clean_data.sort_values('Spread', ascending=False)
low_risk.head()
# Out:
#    Undergraduate Major    Spread  Starting Median Salary  \
# 17           Economics  159400.0                 50100.0
# 22             Finance  147800.0                 47900.0
# 37                Math  137800.0                 45400.0
# 36           Marketing  132900.0                 40800.0
# 42          Philosophy  132500.0                 39900.0
#
#     Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 17                   98600.0                            50600.0
# 22                   88300.0                            47200.0
# 37                   92400.0                            45200.0
# 36                   79600.0                            42100.0
# 42                   81200.0                            35500.0
#
#     Mid-Career 90th Percentile Salary     Group
# 17                           210000.0  Business
# 22                           195000.0  Business
# 37                           183000.0      STEM
# ...

# %%
top_90th_percentile = clean_data.sort_values('Mid-Career 90th Percentile Salary', ascending=False)

# %%
top_90th_percentile.head()
# Out:
#      Undergraduate Major    Spread  Starting Median Salary  \
# 17             Economics  159400.0                 50100.0
# 22               Finance  147800.0                 47900.0
# 8   Chemical Engineering  122100.0                 63200.0
# 37                  Math  137800.0                 45400.0
# 44               Physics  122000.0                 50300.0
#
#     Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 17                   98600.0                            50600.0
# 22                   88300.0                            47200.0
# 8                   107000.0                            71900.0
# 37                   92400.0                            45200.0
# 44                   97300.0                            56000.0
#
#     Mid-Career 90th Percentile Salary     Group
# 17                           210000.0  Business
# 22                           195000.0  Business
# 8                            194000.0      STEM
# ...

# %%
highest_potential = clean_data.sort_values('Mid-Career 90th Percentile Salary', ascending=False)
highest_potential[['Undergraduate Major', 'Mid-Career 90th Percentile Salary']].head()
# Out:
#      Undergraduate Major  Mid-Career 90th Percentile Salary
# 17             Economics                           210000.0
# 22               Finance                           195000.0
# 8   Chemical Engineering                           194000.0
# 37                  Math                           183000.0
# 44               Physics                           178000.0

# %%
highest_potential = clean_data.sort_values("Mid-Career 90th Percentile Salary", ascending=False)
highest_potential[["Undergraduate Major", "Mid-Career 90th Percentile Salary"]].head()
# Out:
#      Undergraduate Major  Mid-Career 90th Percentile Salary
# 17             Economics                           210000.0
# 22               Finance                           195000.0
# 8   Chemical Engineering                           194000.0
# 37                  Math                           183000.0
# 44               Physics                           178000.0

# %%
highest_spread = clean_data.sort_values('Spread', ascending=False)
highest_spread[['Undergraduate Major', 'Spread']].head()
# Out:
#    Undergraduate Major    Spread
# 17           Economics  159400.0
# 22             Finance  147800.0
# 37                Math  137800.0
# 36           Marketing  132900.0
# 42          Philosophy  132500.0

# %%
clean_data.groupby("Group")

# %%
clean_data.groupby("Group").count()
# Out:
#           Undergraduate Major  Spread  Starting Median Salary  \
# Group
# Business                   12      12                      12
# HASS                       22      22                      22
# STEM                       16      16                      16
#
#           Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# Group
# Business                        12                                 12
# HASS                            22                                 22
# STEM                            16                                 16
#
#           Mid-Career 90th Percentile Salary
# Group
# Business                                 12
# HASS                                     22
# STEM                                     16

# %%
grouped_data = clean_data.groupby("Group").count()
grouped_data[['Undergraduate Major']]
# Out:
#           Undergraduate Major
# Group
# Business                   12
# HASS                       22
# STEM                       16

# %%
grouped_data = clean_data.groupby("Group").count()
grouped_data['Undergraduate Major']
# Out:
# Group
# Business    12
# HASS        22
# STEM        16
# Name: Undergraduate Major, dtype: int64

# %%
grouped_data = clean_data.groupby("Group").count()
grouped_data[['Undergraduate Major']]
# Out:
#           Undergraduate Major
# Group
# Business                   12
# HASS                       22
# STEM                       16

# %%
grouped_data = clean_data.groupby("Group").mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    <a href='file:///c%3A/Users/Front%20Desk/AppData/Roaming/Python/Python311/site-packages/pandas/core/groupby/groupby.py?line=1869'>1870</a> try:
# -> <a href='file:///c%3A/Users/Front%20Desk/AppData/Roaming/Python/Python311/site-packages/pandas/core/groupby/groupby.py?line=1870'>1871</a>     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    <a href='file:///c%3A/Users/Front%20Desk/AppData/Roaming/Python/Python311/site-packages/pandas/core/groupby/groupby.py?line=1871'>1872</a> except Exception as err:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
# ...

# %%
grouped_data.mean()
# Out:
# Undergraduate Major                  16.666667
# Spread                               16.666667
# Starting Median Salary               16.666667
# Mid-Career Median Salary             16.666667
# Mid-Career 10th Percentile Salary    16.666667
# Mid-Career 90th Percentile Salary    16.666667
# dtype: float64

# %%
grouped_data = clean_data.groupby("Group").count()
grouped_data['Undergraduate Major'].mean()
# Out:
# 16.666666666666668

# %%
clean_data.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 clean_data.mean()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:11338, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   <a href='file:///c%3A/Users/Front%20Desk/AppData/Roaming/Python/Python311/site-packages/pandas/core/frame.py?line=11329'>11330</a> @doc(make_doc("mean", ndim=2))
#   <a href='file:///c%3A/Users/Front%20Desk/AppData/Roaming/Python/Python311/site-packages/pandas/core/frame.py?line=11330'>11331</a> def mean(
#   <a href='file:///c%3A/Users/Front%20Desk/AppData/Roaming/Python/Python311/site-packages/pandas/core/frame.py?line=11331'>11332</a>     self,
#    (...)
#   <a href='file:///c%3A/Users/Front%20Desk/AppData/Roaming/Python/Python311/site-packages/pandas/core/frame.py?line=11335'>11336</a>     **kwargs,
# ...

# %%
grouped_data = clean_data.groupby("Group").mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    <a href='file:///c%3A/Users/Front%20Desk/AppData/Roaming/Python/Python311/site-packages/pandas/core/groupby/groupby.py?line=1869'>1870</a> try:
# -> <a href='file:///c%3A/Users/Front%20Desk/AppData/Roaming/Python/Python311/site-packages/pandas/core/groupby/groupby.py?line=1870'>1871</a>     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    <a href='file:///c%3A/Users/Front%20Desk/AppData/Roaming/Python/Python311/site-packages/pandas/core/groupby/groupby.py?line=1871'>1872</a> except Exception as err:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
# ...

# %%
clean_data.groupby('Group').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    <a href='file:///c%3A/Users/Front%20Desk/AppData/Roaming/Python/Python311/site-packages/pandas/core/groupby/groupby.py?line=1869'>1870</a> try:
# -> <a href='file:///c%3A/Users/Front%20Desk/AppData/Roaming/Python/Python311/site-packages/pandas/core/groupby/groupby.py?line=1870'>1871</a>     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    <a href='file:///c%3A/Users/Front%20Desk/AppData/Roaming/Python/Python311/site-packages/pandas/core/groupby/groupby.py?line=1871'>1872</a> except Exception as err:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
# ...

# %%
pd.options.display.float_format = '{:,.2f}'.format
clean_data.groupby('Group').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    <a href='file:///c%3A/Users/Front%20Desk/AppData/Roaming/Python/Python311/site-packages/pandas/core/groupby/groupby.py?line=1869'>1870</a> try:
# -> <a href='file:///c%3A/Users/Front%20Desk/AppData/Roaming/Python/Python311/site-packages/pandas/core/groupby/groupby.py?line=1870'>1871</a>     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    <a href='file:///c%3A/Users/Front%20Desk/AppData/Roaming/Python/Python311/site-packages/pandas/core/groupby/groupby.py?line=1871'>1872</a> except Exception as err:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
# ...

# %%
clean_data
# Out:
#                      Undergraduate Major     Spread  Starting Median Salary  \
# 0                             Accounting 109,800.00               46,000.00
# 1                  Aerospace Engineering  96,700.00               57,700.00
# 2                            Agriculture 113,700.00               42,600.00
# 3                           Anthropology 104,200.00               36,800.00
# 4                           Architecture  85,400.00               41,600.00
# 5                            Art History  96,200.00               35,800.00
# 6                                Biology  98,100.00               38,800.00
# 7                    Business Management 108,200.00               43,000.00
# 8                   Chemical Engineering 122,100.00               63,200.00
# 9                              Chemistry 102,700.00               42,600.00
# 10                     Civil Engineering  84,600.00               53,900.00
# ...

# %%
group_data = clean_data.groupby("Group")
group_data.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    <a href='file:///c%3A/Users/Front%20Desk/AppData/Roaming/Python/Python311/site-packages/pandas/core/groupby/groupby.py?line=1869'>1870</a> try:
# -> <a href='file:///c%3A/Users/Front%20Desk/AppData/Roaming/Python/Python311/site-packages/pandas/core/groupby/groupby.py?line=1870'>1871</a>     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    <a href='file:///c%3A/Users/Front%20Desk/AppData/Roaming/Python/Python311/site-packages/pandas/core/groupby/groupby.py?line=1871'>1872</a> except Exception as err:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
# ...

# %%
group_data = clean_data.groupby("Group")
group_data

# %%
clean_data.groupby("Group").mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    <a href='file:///c%3A/Users/Front%20Desk/AppData/Roaming/Python/Python311/site-packages/pandas/core/groupby/groupby.py?line=1869'>1870</a> try:
# -> <a href='file:///c%3A/Users/Front%20Desk/AppData/Roaming/Python/Python311/site-packages/pandas/core/groupby/groupby.py?line=1870'>1871</a>     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    <a href='file:///c%3A/Users/Front%20Desk/AppData/Roaming/Python/Python311/site-packages/pandas/core/groupby/groupby.py?line=1871'>1872</a> except Exception as err:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
# ...

# %%
clean_data.groupby("Group")

# %%
print(clean_data.groupby("Group"))

# %%
clean_data.groupby(["Group"])
